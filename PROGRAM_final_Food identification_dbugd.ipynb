# %% [markdown]
# <a href="https://colab.research.google.com/github/devilgupta/SERVICE---FOOD-IDENTIFICATION-PROGRAM/blob/main/PROGRAM_final_Food%20identification_dbugd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **FOOD CLASSIFICATION PROGRAM**

# %% [markdown]
# # **LIST OF FOODS**
# **30 Indian Foods and 45 multi-cuisine**

# %% [markdown]
# * Rasgulla
# * Palak Paneer
# * Poha
# *Naan
# *Lassi
# *Kofta
# *Jalebi
# *Gulab Jamun
# *Dal
# *Chapati
# *Chicken Tikka
# *Biriyani
# *Aloo matar
# *Aloo Tikki
# *Aloo Gobi
# *Aloo Shimla Mirch
# *Waffle
# *Tacos
# *Sushi
# *Cake
# *Steak
# *Spaghetti
# *Samosa
# *Ramen
# *Pancakes
# *Pizza
# *Nachos
# *Omlette/Eggs
# *Ice cream
# *Soup
# *Hot Dog
# *Burger
# *Frozen Yogurt/Yogurt
# *French Toast
# *Rice
# *Falafel
# *Cupcakes
# *Sandwich
# *Donuts
# *Dumplings
# *Cheescake
# *Burrito
# *Pie
# *Ras malai
# *Phirni
# *Misti doi
# *Karela Bharta
# *Halwa
# *Daal Puri
# *Spring Rolls
# *Boondi
# *Bhatura
# *Fish
# *Risotto
# *Poutine
# *Paella
# *Pad thai
# *Onion rings
# *Ravioli
# *Sandesh
# *Lasagna
# *Laddu
# *Bruschetta
# *Garlic Bread
# *French Fries
# *Churros
# *Chicken/Chicken Wings
# *Quesadillas
# *Chicken Curry
# *Guacamole
# *Baklava
# *Kadai Paneer
# *Ghevar
# *Tiramisu
# *Salad

# %% [markdown]
# ### **Program**

# %% [markdown]
# RUN CELL 1 FOR ONLY ACCESSING GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/Nutrional_Value.zip
# Out:
# Archive:  /content/drive/MyDrive/Nutrional_Value.zip
# replace Nutrional Value/aloo gobi.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import requests
url='https://www.nyckel.com/v1/functions/q6jrfxcg82lnbpp8/invoke'
headers={
    'Authorization': 'Bearer ' + 'eyJhbGciOiJSUzI1NiIsInR5cCI6ImF0K2p3dCJ9.eyJuYmYiOjE2NDUzNzQ2NjcsImV4cCI6MTY0NTM3ODI2NywiaXNzIjoiaHR0cHM6Ly93d3cubnlja2VsLmNvbSIsImNsaWVudF9pZCI6InpqZ3J3dTRsdHJ4YnZ5cndvZWw2cjQ1dDE2bHgzbnIyIiwianRpIjoiNUQxRUVGREE4RjFFQTg1QjUwODQxNjg4MDA2QjFBQjgiLCJpYXQiOjE2NDUzNzQ2NjcsInNjb3BlIjpbImFwaSJdfQ.mD3JBlwGEa5qw4tg9KTRFL0X8Y7G-w7t7n54Cj9UpDVqge-8EV81Pw8hctqjk5Nh3B52fsS411hCISqxwSZkA87_6GpaW70f_RxomNnZknAQSOKa3743wuILZC9bTO4mGLDw9SGjVJ_ITsb6KGx0nQxcI_HDIdWFrJapdj0oSRc7PdeQQYdKNSRPab1SFKXg7WkB_AieqGNvo_qAwpIdKRsGIWg4X1nL8ViT1Qs9-k9-Bjja1QHkqkmyRPpa_7F5T1y-0IYoMe00IZz97eXVYFOZUKUFGYzedVMPl0Ht8rEqHU3CM09at-Vg5hXK5auAE88yZ4XTv7BI1WaXIvJ-eQ'
}

from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(captured_image='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(captured_image, 'wb') as f:
    f.write(binary)
  return captured_image

# %% [markdown]
# RUN CELL 3 FOR CLICKING PHOTO AND CLASSIFYING IT

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator #Class image data generator (we can use it to modify images )
from tensorflow.keras.preprocessing import image #used to transform images into arrays
from tensorflow.keras.optimizers import RMSprop #to improve training and speed of the model, RMS stands for root mean squared
import matplotlib.pyplot as plt #to show graphs 
import tensorflow as tf #import a nueral network
import numpy as np #perform mathematical operations on arrays, convert images into arrays
import cv2 #open source library for video or image analysis 
import os #used to perform the file related functions for python i.e: opening and appending files
from os import system,name
from time import sleep
from IPython.display import Image

try:
  captured_image = take_photo()
 
  # Show the image which was just taken.
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

img=image.load_img(captured_image) #inserting image in the output
plt.imshow(img)
plt.show()

x=image.img_to_array(img) #converting image to array 
x=np.expand_dims(x,axis=0) #for every image a new row in the array will be added
images=np.vstack([x]) #stacking all the array 
with open(captured_image, 'rb') as f: 
  result=requests.post(url, headers=headers,files={'data':f})

confidence=int(result.text[87:89])
confidence_text=float(result.text[87:89]+'.'+result.text[90])
if confidence_text<80:
  print("The system is NOT ABLE to classify the image")
  print("Lead prediction: "+result.text[14:35])
  print('Confidence: ' + str(confidence)+'.'+result.text[90]+'%')
else:
  print(result.text[14:35]) #it will store the class of t
  print('Confidence: ' + str(confidence)+'.'+result.text[90]+'%')
  if confidence<=85 and confidence>=80:
    print("The model is not very sure of the prediction")
  elif confidence<=90 and confidence>=85: 
    print("The model's prediction has a chance of being incorrect")
  elif confidence<=95 and confidence>=90:
    print("The model is confident with the prediction")
  else: 
    print("The model is almost sure of the prediction")
# Out:
# The system is NOT ABLE to classify the image
# Lead prediction: Pizza
# Confidence: 12.4%

# %% [markdown]
# FOR SHOWING NUTRITIONAL VALUE OF THE ABOVE FOOD ITEM!

# %%
from IPython.display import Image, display
print("All these nutritional charts are generalized to the food item itself")
print("To find specific or proportionate nutritional data, visit:")
print("https://www.nutritionix.com/database")
if result.text[14:35] == 'Aloo Gobi            ':
  display(Image('/content/Nutrional Value/aloo gobi.png'))
elif result.text[14:35] == "Aloo matar           ":
  display(Image('/content/Nutrional Value/aloo matar.png'))
elif result.text[14:35] == "Aloo Shimla Mirch    ":
  display(Image('/content/Nutrional Value/aloo shimla mirch.png'))
elif result.text[14:35] == "Aloo Tikki           ":
  display(Image('/content/Nutrional Value/aloo tikki.jpg'))
elif result.text[14:35] == "Baklava              ":
  display(Image('/content/Nutrional Value/baklava.png'))
elif result.text[14:35] == "Bhatura              ":
  display(Image('/content/Nutrional Value/bhatura.png'))
elif result.text[14:35] == "Biriyani             ":
  display(Image('/content/Nutrional Value/biriyani.jpeg'))
elif result.text[14:35] == "Boondi               ":
  display(Image('/content/Nutrional Value/boondi.png'))
elif result.text[14:35] == "Bruschetta           ":
  display(Image('/content/Nutrional Value/bruschetta.png'))
elif result.text[14:35] == "Burger               ":
  display(Image('/content/Nutrional Value/burger.png'))
elif result.text[14:35] == "Burrito              ":
  display(Image('/content/Nutrional Value/burrito.png'))
elif result.text[14:35] == "Cake                 ":
  display(Image('/content/Nutrional Value/cake.png'))
elif result.text[14:35] == "Chapati              ":
  display(Image('/content/Nutrional Value/chapati.jfif'))
elif result.text[14:35] == "Cheescake            ":
  display(Image('/content/Nutrional Value/cheesecake .png'))
elif result.text[14:35] == "Chicken Curry        ":
  display(Image('/content/Nutrional Value/chicken curry.png'))
elif result.text[14:35] == "Chicken Tikka        ":
  display(Image('/content/Nutrional Value/chicken tikka.jpg'))
elif result.text[14:35] == "Chicken/Chicken Wings":
  display(Image('/content/Nutrional Value/chicken wings.png'))
elif result.text[14:35] == "Churros              ":
  display(Image('/content/Nutrional Value/churro.png'))
elif result.text[14:35] == "Cupcakes             ":
  display(Image('/content/Nutrional Value/cupcake.png'))
elif result.text[14:35] == "Daal Puri            ":
  display(Image('/content/Nutrional Value/daal puri.jfif'))
elif result.text[14:35] == "Dal                  ":
  display(Image('/content/Nutrional Value/dal.jpg'))
elif result.text[14:35] == "Donuts               ":
  display(Image('/content/Nutrional Value/donut.png'))
elif result.text[14:35] == "Dumplings            ":
  display(Image('/content/Nutrional Value/dumpling.png'))
elif result.text[14:35] == "Omlette/Eggs         ":
  display(Image('/content/Nutrional Value/eggs.png'))
  display(Image('/content/Nutrional Value/omlette.png'))
elif result.text[14:35] == "Falafel              ":
  display(Image('/content/Nutrional Value/falafel .png'))
elif result.text[14:35] == "Fish                 ":
  display(Image('/content/Nutrional Value/fish.png'))
elif result.text[14:35] == "French Fries         ":
  display(Image('/content/Nutrional Value/french fries.png'))
elif result.text[14:35] == "French Toast         ":
  display(Image('/content/Nutrional Value/french toast .png'))
elif result.text[14:35] == "Frozen Yogurt/Yogurt ":
  display(Image('/content/Nutrional Value/frozen yogurt.png'))
elif result.text[14:35] == "Garlic Bread         ":
  display(Image('/content/Nutrional Value/garlic bread.png'))
elif result.text[14:35] == "Ghevar               ":
  display(Image('/content/Nutrional Value/ghevar.png'))
elif result.text[14:35] == "Guacamole            ":
  display(Image('/content/Nutrional Value/guacamole.png'))
elif result.text[14:35] == "Gulab Jamun          ":
  display(Image('/content/Nutrional Value/gulab jamun.jpg'))
elif result.text[14:35] == "Halwa                ":
  display(Image('/content/Nutrional Value/halwa.png'))
elif result.text[14:35] == "Hot Dog              ":
  display(Image('/content/Nutrional Value/hot dog.png'))
elif result.text[14:35] == "Ice cream            ":
  display(Image('/content/Nutrional Value/icecream.png'))
elif result.text[14:35] == "Jalebi               ":
  display(Image('/content/Nutrional Value/jalebi.jpg'))
elif result.text[14:35] == "Kadai Paneer         ":
  display(Image('/content/Nutrional Value/kadai paneer.png'))
elif result.text[14:35] == "Karela Bharta        ":
  display(Image('/content/Nutrional Value/karela bharta.png'))
elif result.text[14:35] == "Kofta                ":
  display(Image('/content/Nutrional Value/kofta.png'))
elif result.text[14:35] == "Laddu                ":
  display(Image('/content/Nutrional Value/laddu.png'))
elif result.text[14:35] == "Lasagna              ":
  display(Image('/content/Nutrional Value/lasagna.png'))
elif result.text[14:35] == "Lassi                ":
  display(Image('/content/Nutrional Value/lassi.png'))
elif result.text[14:35] == "Misti doi            ":
  display(Image('/content/Nutrional Value/misti doi.png'))
elif result.text[14:35] == "Naan                 ":
  display(Image('/content/Nutrional Value/naan.png'))
elif result.text[14:35] == "Nachos               ":
  display(Image('/content/Nutrional Value/nachos.png'))
elif result.text[14:35] == "Onion rings          ":
  display(Image('/content/Nutrional Value/onion rings.png'))
elif result.text[14:35] == "Pad thai             ":
  display(Image('/content/Nutrional Value/pad thai.png'))
elif result.text[14:35] == "Paella               ":
  display(Image('/content/Nutrional Value/paella.png'))
elif result.text[14:35] == "Palak Paneer         ":
  display(Image('/content/Nutrional Value/palak paneer.png'))
elif result.text[14:35] == "Pancakes             ":
  display(Image('/content/Nutrional Value/pancakes.png'))
elif result.text[14:35] == "Phirni               ":
  display(Image('/content/Nutrional Value/phirni.png'))
elif result.text[14:35] == "Pie                  ":
  display(Image('/content/Nutrional Value/pie.png'))
elif result.text[14:35] == "Pizza                ":
  display(Image('/content/Nutrional Value/pizza.png'))
elif result.text[14:35] == "Poha                 ":
  display(Image('/content/Nutrional Value/poha.jpg'))
elif result.text[14:35] == "Poutine              ":
  display(Image('/content/Nutrional Value/poutine.png'))
elif result.text[14:35] == "Quesadilla           ":
  display(Image('/content/Nutrional Value/quesadilla.png'))
elif result.text[14:35] == "Ramen                ":
  display(Image('/content/Nutrional Value/ramen.png'))
elif result.text[14:35] == "Ras malai            ":
  display(Image('/content/Nutrional Value/ras malai.png'))
elif result.text[14:35] == "Rasgulla             ":
  display(Image('/content/Nutrional Value/rasgulla.jpg'))
elif result.text[14:35] == "Ravioli              ":
  display(Image('/content/Nutrional Value/ravioli.png'))
elif result.text[14:35] == "Rice                 ":
  display(Image('/content/Nutrional Value/rice.png'))
elif result.text[14:35] == "Risotto              ":
  display(Image('/content/Nutrional Value/risotto.png'))
elif result.text[14:35] == "Salad                ":
  display(Image('/content/Nutrional Value/salad.png'))
elif result.text[14:35] == "Samosa               ":
  display(Image('/content/Nutrional Value/samosa.png'))
elif result.text[14:35] == "Sandesh              ":
  display(Image('/content/Nutrional Value/sandesh.png'))
elif result.text[14:35] == "Sandwich             ":
  display(Image('/content/Nutrional Value/sandwich.png'))
elif result.text[14:35] == "Soup                 ":
  display(Image('/content/Nutrional Value/soup.png'))
elif result.text[14:35] == "Spaghetti            ":
  display(Image('/content/Nutrional Value/spaghetti.png'))
elif result.text[14:35] == "Spring Rolls         ":
  display(Image('/content/Nutrional Value/spring rolls.png'))
elif result.text[14:35] == "Steak                ":
  display(Image('/content/Nutrional Value/steak.png'))
elif result.text[14:35] == "Sushi                ":
  display(Image('/content/Nutrional Value/sushi.png'))
elif result.text[14:35] == "Tacos                ":
  display(Image('/content/Nutrional Value/taco.png'))
elif result.text[14:35] == "Tiramisu             ":
  display(Image('/content/Nutrional Value/tiramisu.png'))
elif result.text[14:35] == "Waffle               ":
  display(Image('/content/Nutrional Value/waffle.png'))
elif result.text[14:35] == "Yogurt               ":
  display(Image('/content/Nutrional Value/yogurt.png'))
else:
  print("ERROR")
# Out:
# All these nutritional charts are generalized to the food item itself
# To find specific or proportionate nutritional data, visit:
# https://www.nutritionix.com/database

# %% [markdown]
# RUN CELL 5 FOR UPLOADING AN IMAGE TO RUN THROUGH THE MODEL

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.preprocessing import image 
from tensorflow.keras.optimizers import RMSprop 
import matplotlib.pyplot as plt  
import tensorflow as tf 
import numpy as np 
import cv2 
import os 
from google.colab import files
uploaded = files.upload()

def clear():
  if name == 'nt':
    _ = system('cls')

for fn in uploaded.keys():
  path='/content/{name}'.format(name=fn)

clear()

img=image.load_img(path)
plt.imshow(img)
plt.show()

x=image.img_to_array(img) 
x=np.expand_dims(x,axis=0) 
images=np.vstack([x])

with open(path, 'rb') as f: 
  result1=requests.post(url, headers=headers,files={'data':f})

confidence=int(result1.text[87:89])
confidence_text=float(result1.text[87:89]+'.'+result1.text[90])
if confidence_text<70:
  print("The system is NOT ABLE to classify the image")
  print("Lead prediction: "+result1.text[14:35])
  print('Confidence: ' + str(confidence)+'.'+result1.text[90]+'%')
else:
  print('The Food Item is: '+result1.text[14:35]) 
  print('Confidence: ' + str(confidence)+'.'+result1.text[90]+'%')
  if confidence<=77.5 and confidence>=70:
    print("The model is not very sure of the prediction")
  elif confidence<=85 and confidence>=77.5: 
    print("The model's prediction has a chance of being incorrect")
  elif confidence<=92.5 and confidence>=75:
    print("The model is confident with the prediction")
  else: 
    print("The model is almost sure of the prediction")
# Out:
#      <input type="file" id="files-10255277-7c57-46a5-b861-8bb1566872a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10255277-7c57-46a5-b861-8bb1566872a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 26160.jpg to 26160.jpg
# The Food Item is: Sandwich
# Confidence: 97.3%
# The model is almost sure of the prediction

# %%
from IPython.display import Image, display
print("All these nutritional charts are generalized to the food item itself")
print("To find specific or proportionate nutritional data, visit:")
print("https://www.nutritionix.com/database")
if result1.text[14:35] == 'Aloo Gobi            ':
  display(Image('/content/Nutrional Value/aloo gobi.png'))
elif result1.text[14:35] == "Aloo matar           ":
  display(Image('/content/Nutrional Value/aloo matar.png'))
elif result1.text[14:35] == "Aloo Shimla Mirch    ":
  display(Image('/content/Nutrional Value/aloo shimla mirch.png'))
elif result1.text[14:35] == "Aloo Tikki           ":
  display(Image('/content/Nutrional Value/aloo tikki.jpg'))
elif result1.text[14:35] == "Baklava              ":
  display(Image('/content/Nutrional Value/baklava.png'))
elif result1.text[14:35] == "Bhatura              ":
  display(Image('/content/Nutrional Value/bhatura.png'))
elif result1.text[14:35] == "Biriyani             ":
  display(Image('/content/Nutrional Value/biriyani.jpeg'))
elif result1.text[14:35] == "Boondi               ":
  display(Image('/content/Nutrional Value/boondi.png'))
elif result1.text[14:35] == "Bruschetta           ":
  display(Image('/content/Nutrional Value/bruschetta.png'))
elif result1.text[14:35] == "Burger               ":
  display(Image('/content/Nutrional Value/burger.png'))
elif result1.text[14:35] == "Burrito              ":
  display(Image('/content/Nutrional Value/burrito.png'))
elif result1.text[14:35] == "Cake                 ":
  display(Image('/content/Nutrional Value/cake.png'))
elif result1.text[14:35] == "Chapati              ":
  display(Image('/content/Nutrional Value/chapati.jfif'))
elif result1.text[14:35] == "Cheescake            ":
  display(Image('/content/Nutrional Value/cheesecake .png'))
elif result1.text[14:35] == "Chicken Curry        ":
  display(Image('/content/Nutrional Value/chicken curry.png'))
elif result1.text[14:35] == "Chicken Tikka        ":
  display(Image('/content/Nutrional Value/chicken tikka.jpg'))
elif result1.text[14:35] == "Chicken/Chicken Wings":
  display(Image('/content/Nutrional Value/chicken wings.png'))
elif result1.text[14:35] == "Churros              ":
  display(Image('/content/Nutrional Value/churro.png'))
elif result1.text[14:35] == "Cupcakes             ":
  display(Image('/content/Nutrional Value/cupcake.png'))
elif result1.text[14:35] == "Daal Puri            ":
  display(Image('/content/Nutrional Value/daal puri.jfif'))
elif result1.text[14:35] == "Dal                  ":
  display(Image('/content/Nutrional Value/dal.jpg'))
elif result1.text[14:35] == "Donuts               ":
  display(Image('/content/Nutrional Value/donut.png'))
elif result1.text[14:35] == "Dumplings            ":
  display(Image('/content/Nutrional Value/dumpling.png'))
elif result1.text[14:35] == "Omlette/Eggs         ":
  display(Image('/content/Nutrional Value/eggs.png'))
  display(Image('/content/Nutrional Value/omlette.png'))
elif result1.text[14:35] == "Falafel              ":
  display(Image('/content/Nutrional Value/falafel .png'))
elif result1.text[14:35] == "Fish                 ":
  display(Image('/content/Nutrional Value/fish.png'))
elif result1.text[14:35] == "French Fries         ":
  display(Image('/content/Nutrional Value/french fries.png'))
elif result1.text[14:35] == "French Toast         ":
  display(Image('/content/Nutrional Value/french toast .png'))
elif result1.text[14:35] == "Frozen Yogurt/Yogurt ":
  display(Image('/content/Nutrional Value/frozen yogurt.png'))
elif result1.text[14:35] == "Garlic Bread         ":
  display(Image('/content/Nutrional Value/garlic bread.png'))
elif result1.text[14:35] == "Ghevar               ":
  display(Image('/content/Nutrional Value/ghevar.png'))
elif result1.text[14:35] == "Guacamole            ":
  display(Image('/content/Nutrional Value/guacamole.png'))
elif result1.text[14:35] == "Gulab Jamun          ":
  display(Image('/content/Nutrional Value/gulab jamun.jpg'))
elif result1.text[14:35] == "Halwa                ":
  display(Image('/content/Nutrional Value/halwa.png'))
elif result1.text[14:35] == "Hot Dog              ":
  display(Image('/content/Nutrional Value/hot dog.png'))
elif result1.text[14:35] == "Ice cream            ":
  display(Image('/content/Nutrional Value/icecream.png'))
elif result1.text[14:35] == "Jalebi               ":
  display(Image('/content/Nutrional Value/jalebi.jpg'))
elif result1.text[14:35] == "Kadai Paneer         ":
  display(Image('/content/Nutrional Value/kadai paneer.png'))
elif result1.text[14:35] == "Karela Bharta        ":
  display(Image('/content/Nutrional Value/karela bharta.png'))
elif result1.text[14:35] == "Kofta                ":
  display(Image('/content/Nutrional Value/kofta.png'))
elif result1.text[14:35] == "Laddu                ":
  display(Image('/content/Nutrional Value/laddu.png'))
elif result1.text[14:35] == "Lasagna              ":
  display(Image('/content/Nutrional Value/lasagna.png'))
elif result1.text[14:35] == "Lassi                ":
  display(Image('/content/Nutrional Value/lassi.png'))
elif result1.text[14:35] == "Misti doi            ":
  display(Image('/content/Nutrional Value/misti doi.png'))
elif result1.text[14:35] == "Naan                 ":
  display(Image('/content/Nutrional Value/naan.png'))
elif result1.text[14:35] == "Nachos               ":
  display(Image('/content/Nutrional Value/nachos.png'))
elif result1.text[14:35] == "Onion rings          ":
  display(Image('/content/Nutrional Value/onion rings.png'))
elif result1.text[14:35] == "Pad thai             ":
  display(Image('/content/Nutrional Value/pad thai.png'))
elif result1.text[14:35] == "Paella               ":
  display(Image('/content/Nutrional Value/paella.png'))
elif result1.text[14:35] == "Palak Paneer         ":
  display(Image('/content/Nutrional Value/palak paneer.png'))
elif result1.text[14:35] == "Pancakes             ":
  display(Image('/content/Nutrional Value/pancakes.png'))
elif result1.text[14:35] == "Phirni               ":
  display(Image('/content/Nutrional Value/phirni.png'))
elif result1.text[14:35] == "Pie                  ":
  display(Image('/content/Nutrional Value/pie.png'))
elif result1.text[14:35] == "Pizza                ":
  display(Image('/content/Nutrional Value/pizza.png'))
elif result1.text[14:35] == "Poha                 ":
  display(Image('/content/Nutrional Value/poha.jpg'))
elif result1.text[14:35] == "Poutine              ":
  display(Image('/content/Nutrional Value/poutine.png'))
elif result1.text[14:35] == "Quesadilla           ":
  display(Image('/content/Nutrional Value/quesadilla.png'))
elif result1.text[14:35] == "Ramen                ":
  display(Image('/content/Nutrional Value/ramen.png'))
elif result1.text[14:35] == "Ras malai            ":
  display(Image('/content/Nutrional Value/ras malai.png'))
elif result1.text[14:35] == "Rasgulla             ":
  display(Image('/content/Nutrional Value/rasgulla.jpg'))
elif result1.text[14:35] == "Ravioli              ":
  display(Image('/content/Nutrional Value/ravioli.png'))
elif result1.text[14:35] == "Rice                 ":
  display(Image('/content/Nutrional Value/rice.png'))
elif result1.text[14:35] == "Risotto              ":
  display(Image('/content/Nutrional Value/risotto.png'))
elif result1.text[14:35] == "Salad                ":
  display(Image('/content/Nutrional Value/salad.png'))
elif result1.text[14:35] == "Samosa               ":
  display(Image('/content/Nutrional Value/samosa.png'))
elif result1.text[14:35] == "Sandesh              ":
  display(Image('/content/Nutrional Value/sandesh.png'))
elif result1.text[14:35] == "Sandwich             ":
  display(Image('/content/Nutrional Value/sandwich.png'))
elif result1.text[14:35] == "Soup                 ":
  display(Image('/content/Nutrional Value/soup.png'))
elif result1.text[14:35] == "Spaghetti            ":
  display(Image('/content/Nutrional Value/spaghetti.png'))
elif result1.text[14:35] == "Spring Rolls         ":
  display(Image('/content/Nutrional Value/spring rolls.png'))
elif result1.text[14:35] == "Steak                ":
  display(Image('/content/Nutrional Value/steak.png'))
elif result1.text[14:35] == "Sushi                ":
  display(Image('/content/Nutrional Value/sushi.png'))
elif result1.text[14:35] == "Tacos                ":
  display(Image('/content/Nutrional Value/taco.png'))
elif result1.text[14:35] == "Tiramisu             ":
  display(Image('/content/Nutrional Value/tiramisu.png'))
elif result1.text[14:35] == "Waffle               ":
  display(Image('/content/Nutrional Value/waffle.png'))
elif result1.text[14:35] == "Yogurt               ":
  display(Image('/content/Nutrional Value/yogurt.png'))
else:
  print("ERROR")
# Out:
# All these nutritional charts are generalized to the food item itself
# To find specific or proportionate nutritional data, visit:
# https://www.nutritionix.com/database
